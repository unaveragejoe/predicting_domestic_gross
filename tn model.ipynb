# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

# %%
df = pd.read_pickle('/Users/joe.kholodenko/nyc19_ds18/scrap_folder/tn_df.pkl')

# %%
df['release_date'] = pd.to_numeric(df['release_date'])

# %%
features = ['release_date', 'prod_budget']
target = df['domestic_gross']

df_final = df[features]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df_final, target, test_size=0.33, random_state=42)

# %%
scaler = StandardScaler()

m1 = LinearRegression()
m1.fit(X_train,y_train)
m1.score(X_train,y_train)
# Out:
# 0.500010573300657

# %%
m1.score(X_test,y_test)
# Out:
# 0.44469684929897335

# %%
sns.pairplot(df)

# %%
from sklearn.linear_model import LinearRegression, Ridge #ordinary linear regression + w/ ridge regularization
from sklearn.preprocessing import StandardScaler, PolynomialFeatures

# %%
X_train_scaled = scaler.fit_transform(X_train.values)

X_test_scaled = scaler.transform(X_test.values)

X_scaled = scaler.transform(X_test.values)
# Out:
# /Users/joe.kholodenko/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/joe.kholodenko/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/joe.kholodenko/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/joe.kholodenko/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
df.head()
# Out:
#           release_date                                   movie_name  \
# 0  1261094400000000000                                       avatar
# 1  1305849600000000000  pirates of the caribbean: on stranger tides
# 2  1430438400000000000                      avengers: age of ultron
# 3  1513296000000000000            star wars ep. viii: the last jedi
# 4  1450396800000000000         star wars ep. vii: the force awakens
#
#    prod_budget  domestic_gross  worldwide_gross
# 0    425000000       760507625       2776345279
# 1    410600000       241063875       1045663875
# 2    330600000       459005868       1403013963
# 3    317000000       620181382       1316764784
# 4    306000000       936662225       2053311220
